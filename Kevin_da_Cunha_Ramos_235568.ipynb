# %% [markdown]
# # **Trabalho Final**
# ### Algoritmos e Programação com Linguagem Python
# ---
#
# **Orientações Gerais:**
#
# * Esta é o trabalho final prático onde serão trabalhados conceitos
# apresentados e exercitados em sala de aula.
#
# * Aspéctos como clareza e organização do código, comentários, raciocínio lógico, coerência no nome de variáveis, utilização das estruturas mais adequadas para a solução dos problemas e o funcionamento adequado serão analisados e irão compor o valor da nota final.
#
# * Procure entender exatamente o que se pede antes de iniciar a codificação. Quando se sabe o que é necessário fazer, a codificação fica mais fácil, mais eficiente e mais divertida ;-).
#
# * Faça o upload do notebook completo nomeado da seguinte forma: *nome_sobrenome_RA.ipynb*.
#
# * No caso de grupos, informar ao professor os membros de cada grupo e cada um deverá importar o arquivo no Canvas individualmente.
#
# * Arquivos com nomes incorretos serão desconsiderados!
#
# * Não deixem dúvidas para trás! Acessem os grupos combinados ou entrem em contato com o professor.
#
# ✌ Sucesso o/

# %% [markdown]
# # RMS Titanic
#
# O RMS Titanic foi um navio de passageiros britânico operado pela White Star Line e construído pelos estaleiros da Harland and Wolff em Belfast. Foi a segunda embarcação da Classe Olympic de transatlânticos depois do RMS Olympic e seguido pelo HMHS Britannic. Projetado pelos engenheiros navais Alexander Carlisle e Thomas Andrews, sua construção começou em março de 1909 e ele foi lançado ao mar em maio de 1911. O Titanic foi pensado para ser o navio mais luxuoso e mais seguro de sua época, gerando lendas que era supostamente "inafundável".
#
# A embarcação partiu em sua viagem inaugural de Southampton para Nova Iorque em 10 de abril de 1912, no caminho passando em Cherbourg-Octeville na França e por Queenstown na Irlanda. Ele colidiu com um iceberg às 23h40min do dia 14 de abril e afundou na madrugada do dia seguinte matando mais de 1500 pessoas, sendo um dos maiores desastres marítimos em tempos de paz de toda a história. Seu naufrágio destacou vários pontos fracos de seu projeto, deficiências nos procedimentos de evacuação de emergência e falhas nas regulamentações marítimas da época. Comissões de inquérito foram instauradas nos Estados Unidos e no Reino Unido, levando a mudanças nas leis internacionais de navegação que permanecem em vigor mais de um século depois.
#
# Os destroços do Titanic foram procurados por décadas até serem encontrados em 1985 por uma equipe liderada por Robert Ballard. Ele se encontra a 3843 m de profundidade e a 650 km ao sudeste de Terra Nova no Canadá. Sua história e naufrágio permaneceram no imaginário popular durante décadas, levando a produção de vários livros e filmes a seu respeito, mais notavelmente o filme Titanic de 1997. Até hoje o Titanic permanece como um dos navios mais famosos da história, com seus destroços atraindo várias expedições de exploração ao longo dos anos.
#
# *Fonte:* [WikiPedia](https://pt.wikipedia.org/wiki/RMS_Titanic)
#
# --------

# %% [markdown]
# A equipe da [Udacity](https://udacity.com) disponibilizou informações sobre uma parte dos passageiros à bordo do RMS Titanic no dia daquela tragédia. Esse _dataset_ que contém informações reais vem sendo utilizado em diversos estudos de caso, além de servir de base para aprendizado de Ciência de Dados, Estatística e Machine Learning.
#
# O arquivo **titanic_data.csv** contém informações reais sobre os passageiros organizadas da seguinte forma:
#
# - Survived (Sobreviveu): 0 = Não, 1 = Sim
# - Pclass (Classe): Classe de ingresso 1 = 1º, 2 = 2º, 3 = 3º
# - Sex (Sexo): Sexo do passageiro
# - Age (Idade): Idade em anos
# - Sibsp: Quantidade de irmãos / cônjuges a bordo do Titanic
# - Parch: Quantidade de pais / crianças a bordo do Titanic
# - Ticket (Bilhete): Número do bilhete de embarque
# - Fare (Tarifa): Tarifa paga pelo Passageiro
# - Cabin (Cabine): Número de cabine
# - Embarked (Embarque): Porto de Embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# O objetivo deste estudo é obter algumas informações estatísticas sobre a tragédia e realizar alguns _insights_ a respeito dos tripulantes e das circunstâncias do acidente.
#
# Efetue a carga do arquivo através da biblioteca _Pandas_ e a partir do _DataFrame_ gerado, efetue as operações necessárias para responder as questões.

# %% [markdown]
# ## Importando o DataSet

# %%
##Importando bibliotecas do Pandas, Numpy e biblioteca para gráficos.

import pandas as pd 
import numpy as np 
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.figure_factory as ff

# %% [markdown]
# 1 - Efetuar a leitura do dataset através do Pandas, gerando um DataFrame de nome tit, levando-se em consideração que o arquivo encontra-se na mesma pasta do notebook.

# %%
#lendo o arquivo CSV com pandas
# Variavel tit foi nomeada como se fosse o DatafFrame
tit = pd.read_csv('/content/titanic_data.csv')
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Conhecendo o DataSet

# %% [markdown]
# 2 - Quantas linhas e colunas tem o dataset? Quais os tipos das colunas?

# %%
n_row = tit.shape
print(f'Linhas = {n_row[0]}\nColunas = {n_row[1]}')
# Out:
# Linhas = 891
# Colunas = 12

# %% [markdown]
# 3 - Mostre os dados dos dez primeiros e 8 últimos registros do dataset.

# %%
print('OS 10 PRIMEIROS DADOS'.center(145))
print('_'*145)
display(tit.head(10))

print('\n')
print('OS 8 ÚLTIOS DADOS'.center(145))
print('_'*145)
display(tit.tail(8))
# Out:
#                                                               OS 10 PRIMEIROS DADOS
# _________________________________________________________________________________________________________________________________________________
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# ...

# %% [markdown]
# 4 - Cálculos envolvendo colunas numéricas com dados faltantes podem sofrer impacto. É possível afirmar se há dados faltantes no dataset? Caso positivo, quais e quantos seriam esses dados? Preencha os dados faltantes de forma que não influenciem em operações futuras.

# %%
from pandas.core.window.ewm import ExponentialMovingWindowIndexer
#verificação se há valores nulos
#tit.isna().any() retorna uma serie das colunas --> True = valores nulos | False = Valores não nulos 
#tit.isna().any().any() faz mais um tratamento para ver se a primeira interação do "any()" apresenta valores nulos --> retornado um boleano
if tit.isna().any().any():
  #conta qunatos nulos tem em cada coluna --> retorna uma serie nova serie 
  nulls_value = tit.isna().sum()
  #soma os valore da serie nulls_value
  tota_nulls_value = nulls_value.sum()
  print(f'HÁ {tota_nulls_value} VALORES NULOS')
  print('_'*20)

#Da series nulls_value exclui as linhas de valores 0, pois estamso contando apenas as colunas que possuem valores nulos 
nulls_value = nulls_value.loc[nulls_value != 0]

g1 = px.pie(names=nulls_value.keys(), values=nulls_value)
g1.update_traces(textposition='outside', textinfo='label+value', title = 'VALORES NULOS NO DF POR COLUNA', )
g1.show()
# Out:
# HÁ 866 VALORES NULOS
# ____________________
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
mean = round(tit['Age'].mean(),0)
std = round(tit['Age'].std(),0)

# Gera valores aleatórios com base na média e desvio padrão
random_values = np.random.normal(loc=mean, scale=std, size=tit['Age'].isnull().sum())
random_values = np.clip(random_values, a_min=0, a_max=None)
random_values = np.floor(random_values).astype(int)

# Substitui os valores nulos pelos valores aleatórios gerados
tit.loc[tit['Age'].isnull(), 'Age'] = random_values
tit.loc[tit['Embarked'].isnull(),'Embarked']="Sem informações"
tit.loc[tit['Cabin'].isnull(),'Cabin']="Sem informações"
display(tit)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Adequando o DataSet

# %% [markdown]
# 5 - Uma vez que algumas colunas não serão utilizadas, eventualmente é melhor excluí-las para que não interfiram na análise. Assim, exclua do dataset as colunas Sibsp, Parch e Ticket.

# %%
tit = tit.drop(columns = ['SibSp','Parch','Ticket'])
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ...

# %% [markdown]
# 6 - Renomear as colunas restantes para a lingua portuguesa, utilizando os seguintes nomes de colunas: IdPassageiro, Sobreviveu, Classe, Nome, Sexo, Idade, Tarifa, Cabine e Embarque.

# %%
traducoes = {'PassengerId': 'IdPassageiro',
             'Survived':'Sobreviveu',
             'Pclass':'Classe',
             'Sex':'Sexo',
             'Age':'Idade',
             'Ticket':'Bilhete',
             'Fare':'Tarifa'}
tit = tit.rename(columns = traducoes)
tit
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Name    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# 7 - Alterar o conteudo da coluna Sobreviveu para:
# - 0 => Não
# - 1 => Sim

# %%
tit['Sobreviveu'] = tit['Sobreviveu'].replace(0,'Não')
tit['Sobreviveu'] = tit['Sobreviveu'].replace(1, 'Sim')
tit
# Out:
#      IdPassageiro Sobreviveu  Classe  \
# 0               1        Não       3
# 1               2        Sim       1
# 2               3        Sim       3
# 3               4        Sim       1
# 4               5        Não       3
# ..            ...        ...     ...
# 886           887        Não       2
# 887           888        Sim       1
# 888           889        Não       3
# 889           890        Sim       1
# 890           891        Não       3
#
#                                                   Name    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# 8 - Alterar o conteudo da coluna Sexo para:
# - female => Mulher
# - male   => Homem

# %%
tit['Sexo'] = tit['Sexo'].replace('male','Homem')
tit['Sexo'] = tit['Sexo'].replace('female','Mulher')
tit
# Out:
#      IdPassageiro Sobreviveu  Classe  \
# 0               1        Não       3
# 1               2        Sim       1
# 2               3        Sim       3
# 3               4        Sim       1
# 4               5        Não       3
# ..            ...        ...     ...
# 886           887        Não       2
# 887           888        Sim       1
# 888           889        Não       3
# 889           890        Sim       1
# 890           891        Não       3
#
#                                                   Name    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris   Homem   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Mulher   38.0
# 2                               Heikkinen, Miss. Laina  Mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Mulher   35.0
# 4                             Allen, Mr. William Henry   Homem   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# ## Alguns números

# %% [markdown]
# 9 - Quantas mulheres e quantos homems estavam à bordo, de acordo com o dataset?

# %%
#COMENTAR MELHOR 

contagem_sexo = tit['Sexo'].value_counts()

# criando um gráfico de barras
plt.bar(contagem_sexo.keys(), contagem_sexo)

# adicionando os valores das barras acima delas
for i, v in enumerate(contagem_sexo):
    plt.text(i, v+10, str(v), color='blue', fontweight='bold', ha='center')

# definindo o título e os rótulos dos eixos
plt.title("Quantidade de Mulheres e Homens a bordo")
plt.xlabel("Sexo")
plt.ylabel("Quantidade")

# exibindo o gráfico
plt.show()

# %% [markdown]
# 10 - Quantos passageiros sobreviveram e quantos não sobreviveram?

# %%
contagem_sobreviventes = tit['Sobreviveu'].value_counts()

# Criar um gráfico de barras
plt.bar(contagem_sobreviventes.keys(), contagem_sobreviventes)

# Adicionar o valor acima das barras
for i, v in enumerate(contagem_sobreviventes):
    plt.text(i, v+10, str(v), color='blue', fontweight='bold', ha='center')

# Adicionar título e labels nos eixos
plt.title("Contagem de Sobreviventes e Mortos")
plt.xlabel("Condição")
plt.ylabel("Contagem")

# Mostrar o gráfico
plt.show()

# %% [markdown]
# 11 - Quantas mulheres não sobreviveram?

# %%
mulheres_nao_sobreviventes = (tit[
                                (tit['Sobreviveu'] == "Não") & 
                                (tit['Sexo'] == 'Mulher')
                             ]
                          ).shape[0]

#USADO PARA TESTE 
homens_nao_sobreviventes = (tit[
                                (tit['Sobreviveu'] == "Não") & 
                                (tit['Sexo'] == 'Homem')
                             ]
                          ).shape[0]

print(f'Total de mulheres Mortas foi de : {mulheres_nao_sobreviventes}')
# Out:
# Total de mulheres Mortas foi de : 81

# %% [markdown]
# 12 - Proporcionalmente, sobreviveram mais homens ou mais mulheres? Cite as proporções.

# %%
from matplotlib import colors
filtro_homens = tit.loc[(tit['Sexo'] == 'Homem')]                          
proporcao_sobreviventes_homens = filtro_homens['Sobreviveu'].value_counts()

filtro_mulher = tit.loc[(tit['Sexo'] == 'Mulher')]
proporcao_sobreviventes_mulheres = filtro_mulher['Sobreviveu'].value_counts()


g2 = px.pie(names=proporcao_sobreviventes_homens.keys(), values=proporcao_sobreviventes_homens,
            title='PROPORÇÃO DE HOMENS SOBREVIVENTES', color_discrete_sequence=['#EF553B', '#636EFA'])
g2.show()

g3 = px.pie(names=proporcao_sobreviventes_mulheres.keys(), values=proporcao_sobreviventes_mulheres,
            title='PROPORÇÃO DE MULHERES SOBREVIVENTES', color_discrete_sequence=['#636EFA', '#EF553B'])
g3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 13 - Levando-se em consideração a idade dos passageiros, qual a idade e quantidade de pessoas com o maior número de mortos?

# %%
mortos = tit.loc[(tit['Sobreviveu']=="Não")]


hist_data = [list(mortos['Idade'].values)]  # transforma a lista de dados em uma lista de listas
group_labels = ['Idade dos mortos']  # nome do conjunto de dados --> nesse caso são as idades 



g4 = ff.create_distplot(hist_data, group_labels)#O método create_distplot() do Plotly espera que o argumento hist_data seja uma lista de listas, mesmo que você esteja plotando apenas um conjunto de dados.
g4 = g4.update_layout(bargap=0.4)
g4.show()
moda = mortos['Idade'].mode()
print(moda[0])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 14 - Qual a média de idade dos homens sobreviventes?

# %%
filtro_homens_vivos = filtro_homens.loc[(filtro_homens['Sobreviveu']=='Sim')]
#media das idades dos homens vivos sem conciderar os valores faltantes 
print(f'A média da idade dos Homens sobreviventes é: \n{round(filtro_homens_vivos["Idade"].mean(), 2)}')
# Out:
# A média da idade dos Homens sobreviventes é:
# 27.48

# %% [markdown]
# 15 - Levando-se em consideração passageiros prioritários (mulheres e crianças de até 15 anos independente do sexo) qual a proporção de sobreviventes por sexo?

# %%
#Agrpando passageiros prioritarios
pass_prioritario = tit[
                        (tit['Sexo'] == 'Mulher') |
                        (tit['Idade'] <= 15)  & (tit['Sexo'] == 'Homem')

                      ]

#prporção de sobreviventes entre os homens menores de 15 anos
pass_prioritario = pass_prioritario['Sexo'].value_counts()



g5 = px.pie(names=pass_prioritario.keys(), values=pass_prioritario,
            title='PROPORÇÃO DE PRIORITÁRIOS SOBREVIVENTES',color_discrete_sequence=['#FF6692','#636EFA'])
g5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 16 - Qual a quantidade de passageiros por classe?

# %%
tit['Classe'].value_counts()

g6 = px.histogram(tit['Classe'].value_counts(), title='Distribuição da Classe no Titanic', x=tit['Classe'], labels={'x': 'Classe'})
g6 = g6.update_layout(bargap=0.4)
g6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 17 - Qual o percentual de sobreviventes por classe?

# %%
filtro_classe_1 = tit.loc[(tit['Classe']==1)]
sobreviventes_classe_1 = filtro_classe_1["Sobreviveu"].value_counts()

g7 = px.pie(names=sobreviventes_classe_1.keys(), values=sobreviventes_classe_1,
            title='PROPORÇÃO DE  SOBREVIVENTES CLASSE 1',color_discrete_sequence=['#636EFA','#EF553B'])
g7.show()


filtro_classe_2 = tit.loc[(tit['Classe']==2)]
sobreviventes_classe_2 = filtro_classe_2["Sobreviveu"].value_counts(True)

g8 = px.pie(names=sobreviventes_classe_2.keys(), values=sobreviventes_classe_2,
            title='PROPORÇÃO DE  SOBREVIVENTES CLASSE 2',color_discrete_sequence=['#EF553B','#636EFA'])
g8.show()

filtro_classe_3 = tit.loc[(tit['Classe']==3)]
sobreviventes_classe_3 = filtro_classe_3["Sobreviveu"].value_counts(True)

g9 = px.pie(names=sobreviventes_classe_3.keys(), values=sobreviventes_classe_3,
            title='PROPORÇÃO DE  SOBREVIVENTES CLASSE 2',color_discrete_sequence=['#EF553B','#636EFA'])
g9.show()

filtro_classe_1
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 18 - Crie um dataframe que demonstre a quantidade de sobreviventes e não sobreviventes, agrupados por sexo e classe.

# %%
##agrupando homens da classe 1
SHC1 = tit[
    (tit['Sobreviveu'] == 'Sim') & (tit['Sexo'] == 'Homem') & (tit['Classe'] == 1) 
]
SHC1 = SHC1['Sexo'].value_counts()
##
NHC1 = tit[
    (tit['Sobreviveu'] == 'Não') & (tit['Sexo'] == 'Homem') & (tit['Classe'] == 1) 
]
NHC1 = NHC1['Sexo'].value_counts()
##
##
##agrupando homens da classe 2
SHC2 = tit[
    (tit['Sobreviveu'] == 'Sim') & (tit['Sexo'] == 'Homem') & (tit['Classe'] == 2) 
]
SHC2 = SHC2['Sexo'].value_counts()
##

NHC2 = tit[
    (tit['Sobreviveu'] == 'Não') & (tit['Sexo'] == 'Homem') & (tit['Classe'] == 2) 
]
NHC2 = NHC2['Sexo'].value_counts()
##
##
##agrupando homens da classe 3
SHC3 = tit[
    (tit['Sobreviveu'] == 'Sim') & (tit['Sexo'] == 'Homem') & (tit['Classe'] == 3) 
]
SHC3 = SHC3['Sexo'].value_counts()
##
NHC3 = tit[
    (tit['Sobreviveu'] == 'Não') & (tit['Sexo'] == 'Homem') & (tit['Classe'] == 3) 
]
NHC3 = NHC3['Sexo'].value_counts()
##
##





###AGRUPANDO MULHERES POR CLASSE
###AGRUPANDO MULHERES POR CLASSE
###AGRUPANDO MULHERES POR CLASSE
###AGRUPANDO MULHERES POR CLASSE
###AGRUPANDO MULHERES POR CLASSE


##agrupando Mulheres da classe 1
SMC1 = tit[
    (tit['Sobreviveu'] == 'Sim') & (tit['Sexo'] == 'Mulher') & (tit['Classe'] == 1) 
]
SMC1 = SMC1['Sexo'].value_counts()
##

NMC1 = tit[
    (tit['Sobreviveu'] == 'Não') & (tit['Sexo'] == 'Mulher') & (tit['Classe'] == 1) 
]
NMC1 = NMC1['Sexo'].value_counts()
##
##

##agrupando Mulheres da classe 2
SMC2 = tit[
    (tit['Sobreviveu'] == 'Sim') & (tit['Sexo'] == 'Mulher') & (tit['Classe'] == 2) 
]
SMC2 = SMC2['Sexo'].value_counts()
##

NMC2 = tit[
    (tit['Sobreviveu'] == 'Não') & (tit['Sexo'] == 'Mulher') & (tit['Classe'] == 2) 
]
NMC2 = NMC2['Sexo'].value_counts()
##
##

##agrupando Mulheres da classe 3
SMC3 = tit[
    (tit['Sobreviveu'] == 'Sim') & (tit['Sexo'] == 'Mulher') & (tit['Classe'] == 3) 
]
SMC3 = SMC3['Sexo'].value_counts()
##

NMC3 = tit[
    (tit['Sobreviveu'] == 'Não') & (tit['Sexo'] == 'Mulher') & (tit['Classe'] == 3) 
]
NMC3 = NMC3['Sexo'].value_counts()
##
##


dicionario = {
    'Sexo': ['Masculino', 'Masculino', 'Masculino', 'Feminino', 'Feminino', 'Feminino'],
    'Classe': ['1ª Classe', '2ª Classe', '3ª Classe', '1ª Classe', '2ª Classe', '3ª Classe'],
    'Sobreviveu': [int(SHC1), int(SHC2), int(SHC3), int(SMC1), int(SMC2), int(SMC3)],
    'Não Sobreviveu':[int(NHC1), int(NHC2), int(NHC3), int(NMC1), int(NMC2), int(NMC3)]
}


Novo_dataframe = pd.DataFrame(dicionario)

# exibindo o dataframe
display(Novo_dataframe)
# Out:
#         Sexo     Classe  Sobreviveu  Não Sobreviveu
# 0  Masculino  1ª Classe          45              77
# 1  Masculino  2ª Classe          17              91
# 2  Masculino  3ª Classe          47             300
# 3   Feminino  1ª Classe          91               3
# 4   Feminino  2ª Classe          70               6
# 5   Feminino  3ª Classe          72              72
